# %% [markdown]
# # Exception Handling
# ### it allows python to gracefully handle errors and take corrective actions without stopping execution of the program.

# %%
a=b
# an error will come
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 a=b
#       2 # an error will come
#
# NameError: name 'b' is not defined

# %%
## exception - try, except block
try:
    a=b
except:
    print('The variable has not been assigned')
# Out:
# The variable has not been assigned

# %%
# how to handle exception
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
# zero division error
result = 1/0

# %%
try:
    result =1/0
except ZeroDivisionError as ex:
    print(ex)
    print('Please enter the denominator greater than 0')
# Out:
# division by zero
# Please enter the denominator greater than 0

# %%
# name error in a zero division error handling
try:
    result =1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print('Please enter the denominator greater than 0')
# Out:
# ---------------------------------------------------------------------------
#
# NameError                                 Traceback (most recent call last)
#
# Cell In[42], line 5
#
#       1 # name error in a zero division error handling
#
#       2 try:
#
#       3     result =1/2
#
#       4     a=b
#
# ----> 5 except ZeroDivisionError as ex:
#
#       6     print(ex)
#
#       7     print('Please enter the denominator greater than 0')
#
#
#
# NameError: name 'b' is not defined

# %%
# how to handle multiple 
# name error in a zero division error handling
try:
    result =1/2
    a=b
except ZeroDivisionError as ex:
    print(ex)
    print('Please enter the denominator greater than 0')
except Exception as ex1:#Exception is the parent class of all the error handling so we dont have to specify
    print(ex1)
    print('Main exception got caught here')
# Out:
# name 'b' is not defined
# Main exception got caught here

# %%
try:
    num=int(input('Enter a number'))
    result = 10/num
except ValueError:
    print('This is not a valid number')
except ZeroDivisionError:
    print('enter denominator greater than 0')
except Exception as ex:
    print(ex)
print(result)
# Out:
# 0.29411764705882354

# %%
## try, except, else block

try:
    num=int(input('Enter a number'))
    result = 10/num
except ValueError:
    print('This is not a valid number')
except ZeroDivisionError:
    print('enter denominator greater than 0')
except Exception as ex:
    print(ex)
else:
    print(f'The result is: {result}')  ## this will be printed if there are no errors
# Out:
# enter denominator greater than 0

# %%
# try, except, else, finally block

try:
    num=int(input('Enter a number'))
    result = 10/num
except ValueError:
    print('This is not a valid number')
except ZeroDivisionError:
    print('enter denominator greater than 0')
except Exception as ex:
    print(ex)
else:
    print(f'The result is: {result}')
finally:
    print('Execution complete')  ## this will always be printed whether the error is there or not
# Out:
# This is not a valid number
# Execution complete

# %%
# File handling and exception handling

try:
    file= open('example1.txt', 'r')
    content=file.read()
    print(content)
except FileNotFoundError:
    print('The file does not exist')
except Exception as ex:
    print(ex)

finally:
    if 'file' in locals() or not file.closed:
        file.close()
        print('file close')
# Out:
# file close
