# %% [markdown]
# # Importing python modeules and packages

# %%
import math 
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(16))
print(sqrt(25))
print(pi)
# Out:
# 4.0
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,3,4,5])
# Out:
# array([1, 3, 4, 5])

# %%
from math import *
print(sqrt(67))
print(pi)
# Out:
# 8.18535277187245
# 3.141592653589793

# %%
# custome module 
from package.maths import addition 
addition(2,3)
# Out:
# 5

# %%
from package import maths
maths.addition(2,3)
# Out:
# 5

# %% [markdown]
# # Standard Library Overview
# ### Vast collection of modeules and packages that come with python. Provides a wide range of functionality

# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
# random

import random
print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 8
# cherry

# %%
# File and directory access

import os 
print(os.getcwd())
# Out:
# c:\Users\vidit\Desktop\data-analyst-portfolio\01-Python\Week2-Advanced-Python\notes\03-modules-and-packages

# %%
# make a folder in the given path

os.mkdir('test_dir')

# %%
# High level operations on files and collections of files
import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
# data serialization

import json
data={'name':'vidit', 'age':23}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "vidit", "age": 23}
# <class 'str'>
# {'name': 'vidit', 'age': 23}
# <class 'dict'>

# %%
## CSV

import csv 

with open('example.csv', mode = 'w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name', 'age'])
    writer.writerow(['vidit', 23])

with open('example.csv', mode = 'r')as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['vidit', '23']

# %%
# datetime
from datetime import datetime, timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-05-31 21:22:06.501209
# 2026-05-30 21:22:06.501209

# %%
# time 
import time 
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1780242777.2055655
# 1780242779.2069428

# %%
# regular expression

import re

pattern= r'\d+'
text = 'there are 123 apples'
match = re.search(pattern,text)
print(match.group())
# Out:
# 123
