# %% [markdown]
# # lmada functions
# ### small anonymous functions defined using **lamda** keyword. anaoymous functions are functions without a name. they can have any number of arguments but only one expression. commonly used for short operations or arguments.

# %%
# syntax

lambda arguments : expression

# %%
def addition(a,b):
    return a+b

# %%
addition(2,6)
# Out:
# 8

# %%
# lambda function
addition = lambda a,b: a+b
type(addition)
print(addition(5,6))
# Out:
# 11

# %%
def even(num):
    if num%2==0:
        return True

print(even(24))
# Out:
# True

# %%
even1 = lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)
# Out:
# 39

# %%
addition1 = lambda x,y,z: x+y+z
addition1(12,13,14)
# Out:
# 39

# %%
# map function - it applies a function to all items in the list
numbers = [1,2,3,4,5,6]
def square(number):
    return number**2

square(2)
# Out:
# 4

# %%
list(map(lambda x:x**2, numbers))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
# map function 

def square(x):
    return x*x

square(4)
# Out:
# 16

# %%
numbers=[1,2,3,4,5,6,7,8]

list(map(square, numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# lambda function with map
numbers=[1,2,3,4,5,6,7,8]
list(map(lambda x:x*x, numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
# map multiple iterables

numbers1=[1,2,3]
numbers2=[4,5,6]

added_num=list(map(lambda x,y:x+y, numbers1, numbers2))
print(added_num)
# Out:
# [5, 7, 9]

# %%
## map() to convert list of strings to integers

str_num = ['1', '2', '3', '4', '5']
int_num= list(map(int, str_num))

print(int_num)
# Out:
# [1, 2, 3, 4, 5]

# %%
words=['apple', 'banana', 'cherry']
upper_words = list(map(str.upper, words))
print(upper_words)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
def get_name(person):
    return person['name']

people = [
    
]
